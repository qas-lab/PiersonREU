# %%
import pandas as pd
# !pip install scikit-learn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import os
import matplotlib.pyplot as plt    
import seaborn as sns      
import joblib
# Out:
# Requirement already satisfied: scikit-learn in /home/rpierson/anaconda3/envs/firstenvi/lib/python3.11/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/rpierson/anaconda3/envs/firstenvi/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/rpierson/anaconda3/envs/firstenvi/lib/python3.11/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/rpierson/anaconda3/envs/firstenvi/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/rpierson/anaconda3/envs/firstenvi/lib/python3.11/site-packages (from scikit-learn) (3.5.0)

# %%
#Importing Data
to_train = pd.read_csv('/home/rpierson/PiersonREU/extracted/train_dataset.csv')
data = to_train.copy()
priority = pd.read_csv('/home/rpierson/PiersonREU/extracted/train_priority.csv')

# %%
#Combining Textual Elements
data['Combined_Text'] = data["Title"] + " " + data["Component"] + " " + data["Description"]
data.head()
# Out:
#        Issue_id Priority                                              Title  \
# 0             1       P3    Usability issue with external editors (1GE6IRL)
# 1            13       P3          CC Discussion: local versioning (1GAT3PL)
# 2            12       P3     Manage/unmanage support and policies (1GALAEG)
# 3            11       P3  API: ISharingManager::load mapping vcm project...
# 4            10       P3             API - VCM event notification (1G8G6RR)
# ...         ...      ...                                                ...
# 68119    229777       P3  [Viewers] Wrong argument in the first statemen...
# 68120    229779       P3                           NPE in performance tests
# 68121    229782       P3                 Performance tests for ICU Collator
# 68122    229789       P3  [Examples] examples plugins create duplicate m...
# 68123    229792       P3  Collapse All and Expand All buttons are separated
#
#                                              Description Component  \
# 0      - Setup a project that contains a *.gif resour...      Team
# 1      Would it make sense to have a (the?) projects ...      Team
# 2      Currently every new resource added to a shared...      Team
# 3      Jean-Michel (08/02/2001 1:38:48 PM); ; The ISh...      Team
# 4      There seems to be a need for a VCM Event notif...      Team
# ...                                                  ...       ...
# 68119  Build ID: 3.3 (I am not sure what You mean by ...        UI
# 68120  There are several NPEs within the UI session t...        UI
# 68121  I20080501-0100; ; Now that were using the coll...        UI
# 68122  Created attachment 98318; screenshot; ; I20080...        UI
# 68123  Build ID: M20080221-1800; ; Steps To Reproduce...      Team
#
#                                            Combined_Text
# 0      Usability issue with external editors (1GE6IRL...
# 1      CC Discussion: local versioning (1GAT3PL) Team...
# 2      Manage/unmanage support and policies (1GALAEG)...
# 3      API: ISharingManager::load mapping vcm project...
# 4      API - VCM event notification (1G8G6RR) Team Th...
# ...                                                  ...
# 68119  [Viewers] Wrong argument in the first statemen...
# 68120  NPE in performance tests UI There are several ...
# 68121  Performance tests for ICU Collator UI I2008050...
# 68122  [Examples] examples plugins create duplicate m...
# 68123  Collapse All and Expand All buttons are separa...
#
# [68124 rows x 6 columns]

# %%
#Viewing Specific Text
data['Combined_Text'][0:1]
# Out:
# 0    Usability issue with external editors (1GE6IRL...
# Name: Combined_Text, dtype: object

# %%
#Needed List Format
texts = data['Combined_Text'].tolist()

# %%
#Need Vector for LDA
vectorizer = CountVectorizer() #Part of Sklearn, converts into matrix of token counts

# %%
#Training Vectorizer on Our Text and transforms our data
x = vectorizer.fit_transform(texts) #turns data into vectors

# %%
#Creating our topics
num_topics = 10
lda = LatentDirichletAllocation(n_components=num_topics,
    random_state=0) #Specifics of this model, ten topics

# %%
#Fitting data into topics
lda.fit(x) #Run through our data
# Out:
# LatentDirichletAllocation(random_state=0)

# %%
topic_distributions = lda.transform(x) #Method to get topic dists for each bug
topics = []

# %%
for topic_dist in topic_distributions:
    dominant_topic = topic_dist.argmax()
    topics.append(dominant_topic)

# %%
data['Topic'] = topics

# %%
data
# Out:
#        Issue_id Priority                                              Title  \
# 0             1       P3    Usability issue with external editors (1GE6IRL)
# 1            13       P3          CC Discussion: local versioning (1GAT3PL)
# 2            12       P3     Manage/unmanage support and policies (1GALAEG)
# 3            11       P3  API: ISharingManager::load mapping vcm project...
# 4            10       P3             API - VCM event notification (1G8G6RR)
# ...         ...      ...                                                ...
# 68119    229777       P3  [Viewers] Wrong argument in the first statemen...
# 68120    229779       P3                           NPE in performance tests
# 68121    229782       P3                 Performance tests for ICU Collator
# 68122    229789       P3  [Examples] examples plugins create duplicate m...
# 68123    229792       P3  Collapse All and Expand All buttons are separated
#
#                                              Description Component  \
# 0      - Setup a project that contains a *.gif resour...      Team
# 1      Would it make sense to have a (the?) projects ...      Team
# 2      Currently every new resource added to a shared...      Team
# 3      Jean-Michel (08/02/2001 1:38:48 PM); ; The ISh...      Team
# 4      There seems to be a need for a VCM Event notif...      Team
# ...                                                  ...       ...
# 68119  Build ID: 3.3 (I am not sure what You mean by ...        UI
# 68120  There are several NPEs within the UI session t...        UI
# 68121  I20080501-0100; ; Now that were using the coll...        UI
# 68122  Created attachment 98318; screenshot; ; I20080...        UI
# 68123  Build ID: M20080221-1800; ; Steps To Reproduce...      Team
#
#                                            Combined_Text  Topic
# 0      Usability issue with external editors (1GE6IRL...      9
# 1      CC Discussion: local versioning (1GAT3PL) Team...      9
# 2      Manage/unmanage support and policies (1GALAEG)...      9
# 3      API: ISharingManager::load mapping vcm project...      9
# 4      API - VCM event notification (1G8G6RR) Team Th...      9
# ...                                                  ...    ...
# 68119  [Viewers] Wrong argument in the first statemen...      9
# 68120  NPE in performance tests UI There are several ...      9
# 68121  Performance tests for ICU Collator UI I2008050...      9
# 68122  [Examples] examples plugins create duplicate m...      9
# 68123  Collapse All and Expand All buttons are separa...      9
#
# [68124 rows x 7 columns]

# %%
data.groupby('Topic').count()
# Out:
#        Issue_id  Priority  Title  Description  Component  Combined_Text
# Topic
# 0          1030      1030   1030         1030       1030           1030
# 1           527       527    527          527        527            527
# 2           301       301    301          301        301            301
# 3           744       744    744          744        744            744
# 4          6611      6611   6611         6611       6611           6611
# 5          1718      1718   1718         1718       1718           1718
# 6          2155      2155   2155         2155       2155           2155
# 7          1568      1568   1568         1568       1568           1568
# 8           539       539    539          539        539            539
# 9         52931     52931  52931        52931      52931          52931

# %%
extract_dir = '/home/rpierson/PiersonREU/extracted'
data_file = os.path.join(extract_dir, 'train_dataset.csv')
data.to_csv(data_file, index = False)

# %%
gr = data.groupby('Topic')['Combined_Text'].count()
gr
# Out:
# Topic
# 0     1030
# 1      527
# 2      301
# 3      744
# 4     6611
# 5     1718
# 6     2155
# 7     1568
# 8      539
# 9    52931
# Name: Combined_Text, dtype: int64

# %%
#Created visualization, turned into pie chart in other code instead
plt.xticks(rotation = 0)
plt.grid(axis='y', color='black', alpha=0.3)
plt.title('Total Number of Training Data Bug Reports in Each Topic')

# Here we use plot the grouped index on the x axis and the values on the y axis
sns.barplot(x = gr.index, y = gr.values)

plt.show()

# %%
#Saving lda and vec trained for each topic
extract_dir = '/home/rpierson/PiersonREU/extracted'
lda_file = os.path.join(extract_dir, 'lda.pkl')
joblib.dump(lda, lda_file)
#lda.to_pkl(data_file, index = False)

vec_file = os.path.join(extract_dir, 'vec.pkl')
joblib.dump(vectorizer, vec_file)
#vectorizer.to_pkl(vec_file, index = False)
# Out:
# ['/home/rpierson/PiersonREU/extracted/vec.pkl']

# %%
joblib.dump(lda, lda_file)
joblib.dump(vectorizer, vec_file)
# Out:
# ['/home/rpierson/PiersonREU/extracted/vec.pkl']

# %%
#Making priorities easier for process
label_map = {'P1': 1, 'P2': 2, 'P3': 3, 'P4': 4, 'P5': 5}
data['Priority'] = data['Priority'].map(label_map)

# %%
#Saving
extract_dir = '/home/rpierson/Topic_Files'

topic_data = {topic_label: {'Combined_Text': [], 'Priority': []} for topic_label in range(num_topics)}

# Accumulate data for each topic
for index, row in data.iterrows():
    topic_label = row['Topic']
    content = row['Combined_Text']
    priority = row['Priority']
    
    topic_data[topic_label]['Combined_Text'].append(content)
    topic_data[topic_label]['Priority'].append(priority)

# Write each topic's data to a CSV file
for topic_label, data_dict in topic_data.items():
    df = pd.DataFrame(data_dict)
    csv_file_path = f'{extract_dir}/topic_{topic_label}.csv'
    df.to_csv(csv_file_path, index=False)

print("Files have been written successfully.")
# Out:
# Files have been written successfully.
