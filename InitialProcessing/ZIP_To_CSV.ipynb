# %%
# !pip install pandas
# !pip install scipy
# !pip install matplotlib
# !pip install seaborn
# !pip install tensorflow
import zipfile
import os
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import xml.etree.ElementTree as ET
import tensorflow as tf
# Out:
# ...
# 2024-06-21 15:25:23.671867: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-21 15:25:23.675681: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-21 15:25:23.724939: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-21 15:25:24.552889: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#To Start Working With Dataset
uploaded_zip = '/home//bughub/EclipsePlatform/eclipse_platform.zip'
extract_dir = '/home//bughub/extracted'
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)
with zipfile.ZipFile(uploaded_zip, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

csv_file = os.path.join(extract_dir, 'eclipse_platform.csv')
fulldata = pd.read_csv(csv_file)

# %%
#Viewing Data
fulldata.head()
# Out:
#    Issue_id Priority Component  Duplicated_issue  \
# 0         1       P3      Team               NaN
# 1         2       P5      Team               NaN
# 2         3       P5      Team               NaN
# 3         4       P5      Team               NaN
# 4         5       P3      Team               NaN
#
#                                                Title  \
# 0    Usability issue with external editors (1GE6IRL)
# 1  Opening repository resources doesnt honor type...
# 2          Sync does not indicate deletion (1GIEN83)
# 3  need better error message if catching up over ...
# 4  ISharingManager sharing API inconsistent (1GAU...
#
#                                          Description    Status Resolution  \
# 0  - Setup a project that contains a *.gif resour...    CLOSED      FIXED
# 1  Opening repository resource always open the de...  RESOLVED      FIXED
# 2  KM (10/2/2001 5:55:18 PM); \tThis PR about the...  RESOLVED      FIXED
# ...
